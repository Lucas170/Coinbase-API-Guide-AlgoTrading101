# %%
pip install coinbase
# Out:
# Collecting coinbase
#   Downloading coinbase-2.1.0.tar.gz (68 kB)
# Requirement already satisfied: requests>=2.5 in c:\users\igorr\anaconda3\lib\site-packages (from coinbase) (2.24.0)
# Requirement already satisfied: six>=1.9 in c:\users\igorr\anaconda3\lib\site-packages (from coinbase) (1.15.0)
# Collecting pycryptodome>=3.4.11
#   Downloading pycryptodome-3.9.8-cp38-cp38-win_amd64.whl (14.1 MB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\igorr\anaconda3\lib\site-packages (from requests>=2.5->coinbase) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\igorr\anaconda3\lib\site-packages (from requests>=2.5->coinbase) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\igorr\anaconda3\lib\site-packages (from requests>=2.5->coinbase) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\igorr\anaconda3\lib\site-packages (from requests>=2.5->coinbase) (2.10)
# Building wheels for collected packages: coinbase
#   Building wheel for coinbase (setup.py): started
#   Building wheel for coinbase (setup.py): finished with status 'done'
#   Created wheel for coinbase: filename=coinbase-2.1.0-py2.py3-none-any.whl size=20975 sha256=0f9a8ff93ae65e0bc22348cac762d1f066adef96021686637337383a9005cbd7
#   Stored in directory: c:\users\igorr\appdata\local\pip\cache\wheels\f2\2c\36\5b2732d89b254106df810d25f8430ec1935c2ec6b9dc28be41
# Successfully built coinbase
# Installing collected packages: pycryptodome, coinbase
# Successfully installed coinbase-2.1.0 pycryptodome-3.9.8
# Note: you may need to restart the kernel to use updated packages.

# %%
from coinbase.wallet.client import Client

coinbase_API_Key = "AGD9NWan8s73aKkK"
coinbase_API_Secret = "TZxiwi46hziLMztyP8BmGHEXANbdUEHm"

Client = Client(coinbase_API_Key, coinbase_API_Secret)

# %%
total = 0
message = [ ]

# %%
accounts = Client.get_accounts()
for wallet in accounts.data:
    message.append( str(wallet['name']) + ' ' +   str(wallet['native_balance']) )
    value = str( wallet['native_balance']).replace('USD','')
    total += float(value)
message.append( 'Total Balance: ' + 'USD ' + str(total) )
print ('\n'.join( message ))
# Out:
# BTC Wallet USD 0.00
# BCH Wallet USD 0.00
# ETH Wallet USD 0.00
# ETC Wallet USD 0.00
# LTC Wallet USD 0.00
# ZRX Wallet USD 0.00
# BAT Wallet USD 0.00
# USDC Wallet USD 0.00
# ZEC Wallet USD 0.00
# MKR Wallet USD 0.00
# DAI Wallet USD 0.00
# OMG Wallet USD 0.00
# KNC Wallet USD 0.00
# LINK Wallet USD 0.00
# XRP Wallet USD 0.00
# REP Wallet USD 0.00
# XLM Wallet USD 0.00
# EOS Wallet USD 0.00
# XTZ Wallet USD 0.00
# ALGO Wallet USD 0.00
# DASH Wallet USD 0.00
# ATOM Wallet USD 0.00
# OXT Wallet USD 0.00
# COMP Wallet USD 0.00
# REPV2 Wallet USD 0.00
# BAND Wallet USD 0.00
# NMR Wallet USD 0.00
# CGLD Wallet USD 0.00
# LRC Wallet USD 0.00
# UMA Wallet USD 0.00
# YFI Wallet USD 0.00
# UNI Wallet USD 0.00
# BAL Wallet USD 0.00
# REN Wallet USD 0.00
# WBTC Wallet USD 0.00
# Total Balance: USD 0.0
# BTC Wallet USD 0.00
# BCH Wallet USD 0.00
# ETH Wallet USD 0.00
# ETC Wallet USD 0.00
# LTC Wallet USD 0.00
# ZRX Wallet USD 0.00
# BAT Wallet USD 0.00
# USDC Wallet USD 0.00
# ZEC Wallet USD 0.00
# MKR Wallet USD 0.00
# DAI Wallet USD 0.00
# OMG Wallet USD 0.00
# KNC Wallet USD 0.00
# LINK Wallet USD 0.00
# XRP Wallet USD 0.00
# REP Wallet USD 0.00
# XLM Wallet USD 0.00
# EOS Wallet USD 0.00
# XTZ Wallet USD 0.00
# ALGO Wallet USD 0.00
# DASH Wallet USD 0.00
# ATOM Wallet USD 0.00
# OXT Wallet USD 0.00
# COMP Wallet USD 0.00
# REPV2 Wallet USD 0.00
# BAND Wallet USD 0.00
# NMR Wallet USD 0.00
# CGLD Wallet USD 0.00
# LRC Wallet USD 0.00
# UMA Wallet USD 0.00
# YFI Wallet USD 0.00
# UNI Wallet USD 0.00
# BAL Wallet USD 0.00
# REN Wallet USD 0.00
# WBTC Wallet USD 0.00
# Total Balance: USD 0.0
# BTC Wallet USD 0.00
# BCH Wallet USD 0.00
# ETH Wallet USD 0.00
# ETC Wallet USD 0.00
# LTC Wallet USD 0.00
# ZRX Wallet USD 0.00
# BAT Wallet USD 0.00
# USDC Wallet USD 0.00
# ZEC Wallet USD 0.00
# MKR Wallet USD 0.00
# DAI Wallet USD 0.00
# OMG Wallet USD 0.00
# KNC Wallet USD 0.00
# LINK Wallet USD 0.00
# XRP Wallet USD 0.00
# REP Wallet USD 0.00
# XLM Wallet USD 0.00
# EOS Wallet USD 0.00
# XTZ Wallet USD 0.00
# ALGO Wallet USD 0.00
# DASH Wallet USD 0.00
# ATOM Wallet USD 0.00
# OXT Wallet USD 0.00
# COMP Wallet USD 0.00
# REPV2 Wallet USD 0.00
# BAND Wallet USD 0.00
# NMR Wallet USD 0.00
# CGLD Wallet USD 0.00
# LRC Wallet USD 0.00
# UMA Wallet USD 0.00
# YFI Wallet USD 0.00
# UNI Wallet USD 0.00
# BAL Wallet USD 0.00
# REN Wallet USD 0.00
# WBTC Wallet USD 0.00
# Total Balance: USD 0.0
# BTC Wallet USD 0.00
# BCH Wallet USD 0.00
# ETH Wallet USD 0.00
# ETC Wallet USD 0.00
# LTC Wallet USD 0.00
# ZRX Wallet USD 0.00
# BAT Wallet USD 0.00
# USDC Wallet USD 0.00
# ZEC Wallet USD 0.00
# MKR Wallet USD 0.00
# DAI Wallet USD 0.00
# OMG Wallet USD 0.00
# KNC Wallet USD 0.00
# LINK Wallet USD 0.00
# XRP Wallet USD 0.00
# REP Wallet USD 0.00
# XLM Wallet USD 0.00
# EOS Wallet USD 0.00
# XTZ Wallet USD 0.00
# ALGO Wallet USD 0.00
# DASH Wallet USD 0.00
# ATOM Wallet USD 0.00
# OXT Wallet USD 0.00
# COMP Wallet USD 0.00
# REPV2 Wallet USD 0.00
# BAND Wallet USD 0.00
# NMR Wallet USD 0.00
# CGLD Wallet USD 0.00
# LRC Wallet USD 0.00
# UMA Wallet USD 0.00
# YFI Wallet USD 0.00
# UNI Wallet USD 0.00
# BAL Wallet USD 0.00
# REN Wallet USD 0.00
# WBTC Wallet USD 0.00
# Total Balance: USD 0.0
