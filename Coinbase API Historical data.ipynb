# %%
from coinbase.wallet.client import Client
from coinbase.wallet.model import APIObject
import pandas as pd

# %%
coinbase_API_Key = "AGD9NWan8s73aKkK"
coinbase_API_Secret = "TZxiwi46hziLMztyP8BmGHEXANbdUEHm"

client = Client(coinbase_API_Key, coinbase_API_Secret)
client._make_api_object(client._get('v2', 'prices', 'ETH-EUR', 'historic'), APIObject)
# Out:
# <APIObject @ 0x1b0eedead10> {
#   "base": "ETH",
#   "currency": "EUR",
#   "prices": [
#     {
#       "price": "344.06",
#       "time": "2020-10-25T19:35:30Z"
#     },
#     {
#       "price": "344.12",
#       "time": "2020-10-25T19:35:20Z"
#     },
#     {
#       "price": "344.18",
#       "time": "2020-10-25T19:35:00Z"
#     },
#     {
#       "price": "344",
#       "time": "2020-10-25T19:34:50Z"
#     },
#     {
#       "price": "344.13",
#       "time": "2020-10-25T19:34:40Z"
#     },
#     {
#       "price": "343.92",
#       "time": "2020-10-25T19:33:50Z"
#     },
#     {
#       "price": "344.07",
#       "time": "2020-10-25T19:33:20Z"
#     },
#     {
#       "price": "344.06",
#       "time": "2020-10-25T19:32:50Z"
#     },
#     {
#       "price": "343.97",
#       "time": "2020-10-25T19:32:40Z"
#     },
#     {
#       "price": "344",
#       "time": "2020-10-25T19:32:00Z"
#     },
#     {
#       "price": "344.08",
#       "time": "2020-10-25T19:31:50Z"
#     },
# ...

# %%
data = [['344.06','2020-10-25'], ['344.12','2020-10-25'],['344.18','2020-10-25'],['344','2020-10-25']]

df =pd.DataFrame(data,columns=['Price','Time'])
df
# Out:
#     Price        Time
# 0  344.06  2020-10-25
# 1  344.12  2020-10-25
# 2  344.18  2020-10-25
# 3     344  2020-10-25
